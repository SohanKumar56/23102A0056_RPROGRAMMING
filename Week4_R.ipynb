# %% [markdown]
# <a href="https://colab.research.google.com/github/SohanKumar56/23102A0056_RPROGRAMMING/blob/main/Week4_R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name: Sohan Kumar
#
# Roll no: 23102A0056
#
# Branch: CMPN-A

# %% [markdown]
# ### 1. Creating a Matrix

# %%
x <- matrix(nrow = 4, ncol = 3, data = c(1:12))
x
# Out:
#      [,1] [,2] [,3]
# [1,] 1    5     9
# [2,] 2    6    10
# [3,] 3    7    11
# [4,] 4    8    12

# %% [markdown]
# ### 2. Renaming the Names of Rows and Columns

# %%
rownames(x) <- c("r1", "r2", "r3", "r4")
colnames(x) <- c("c1", "c2", "c3")
x
# Out:
#    c1 c2 c3
# r1 1  5   9
# r2 2  6  10
# r3 3  7  11
# r4 4  8  12

# %% [markdown]
# ### 3. Assigning a Specified Number to All Matrix Elements

# %%
x <- matrix(nrow = 4, ncol = 2, data = 2)
x
# Out:
#      [,1] [,2]
# [1,] 2    2
# [2,] 2    2
# [3,] 2    2
# [4,] 2    2

# %% [markdown]
# ### 4. Construction of a Diagonal / Identity Matrix

# %%
d <- diag(1, nrow = 3, ncol = 3)
d
# Out:
#      [,1] [,2] [,3]
# [1,] 1    0    0
# [2,] 0    1    0
# [3,] 0    0    1

# %% [markdown]
# ### 5. Diagonal Matrix with All Diagonal Elements Equal to 5

# %%
d <- diag(5, nrow = 3, ncol = 3)
d
# Out:
#      [,1] [,2] [,3]
# [1,] 5    0    0
# [2,] 0    5    0
# [3,] 0    0    5

# %% [markdown]
# ### 6. Transpose of a Matrix

# %%
x <- matrix(nrow = 4, ncol = 2, data = 1:8, byrow = TRUE)
x

xt <- t(x)
xt
# Out:
#      [,1] [,2]
# [1,] 1    2
# [2,] 3    4
# [3,] 5    6
# [4,] 7    8
#      [,1] [,2] [,3] [,4]
# [1,] 1    3    5    7
# [2,] 2    4    6    8

# %% [markdown]
# ### 7. Finding Row and Column Sums

# %%
x <- matrix(nrow = 4, ncol = 2, data = c(1,2,3,4,5,6,7,8))
x

rowSums(x)
colSums(x)
# Out:
#      [,1] [,2]
# [1,] 1    5
# [2,] 2    6
# [3,] 3    7
# [4,] 4    8
# [1]  6  8 10 12
# [1] 10 26

# %% [markdown]
# ### 8. Finding Row and Column Means

# %%
x <- matrix(nrow = 4, ncol = 2, data = c(1,2,3,4,5,6,7,8))
x

rowMeans(x)
colMeans(x)
# Out:
#      [,1] [,2]
# [1,] 1    5
# [2,] 2    6
# [3,] 3    7
# [4,] 4    8
# [1] 3 4 5 6
# [1] 2.5 6.5

# %% [markdown]
# ### 9. Creating a Matrix by Row

# %%
x <- matrix(nrow = 5, ncol = 3, byrow = TRUE, data = 1:15)
x
# Out:
#      [,1] [,2] [,3]
# [1,]  1    2    3
# [2,]  4    5    6
# [3,]  7    8    9
# [4,] 10   11   12
# [5,] 13   14   15

# %% [markdown]
# ### 10. Accessing a Row

# %%
x[3,]
# Out:
# [1] 7 8 9

# %% [markdown]
# ### 11. Accessing a Column

# %%
x[,2]
# Out:
# [1]  2  5  8 11 14

# %% [markdown]
# ### 12. Accessing a Submatrix

# %%
x[4:5, 2:3]
# Out:
#      [,1] [,2]
# [1,] 11   12
# [2,] 14   15

# %% [markdown]
# ### 13. Accessing Selected Rows and Columns

# %%
x[c(1,4), c(1,3)]
# Out:
#      [,1] [,2]
# [1,]  1    3
# [2,] 10   12

# %% [markdown]
# ### 14. Selecting a Column from a Matrix

# %%
x[,2]
# Out:
# [1]  2  5  8 11 14

# %% [markdown]
# ### 15. Addition of a Matrix with a Constant

# %%
x <- matrix(nrow = 4, ncol = 2, data = 1:8, byrow = TRUE)
x
x + 5
# Out:
#      [,1] [,2]
# [1,] 1    2
# [2,] 3    4
# [3,] 5    6
# [4,] 7    8
#      [,1] [,2]
# [1,]  6    7
# [2,]  8    9
# [3,] 10   11
# [4,] 12   13

# %% [markdown]
# ### 16. Subtraction of a Matrix with a Constant

# %%
x <- matrix(nrow = 4, ncol = 2, data = 1:8, byrow = TRUE)
x
x - 5
# Out:
#      [,1] [,2]
# [1,] 1    2
# [2,] 3    4
# [3,] 5    6
# [4,] 7    8
#      [,1] [,2]
# [1,] -4   -3
# [2,] -2   -1
# [3,]  0    1
# [4,]  2    3

# %% [markdown]
# ### 17. Multiplication of a Matrix with a Constant

# %%
x <- matrix(nrow = 4, ncol = 2, data = 1:8, byrow = TRUE)
x
5 * x
# Out:
#      [,1] [,2]
# [1,] 1    2
# [2,] 3    4
# [3,] 5    6
# [4,] 7    8
#      [,1] [,2]
# [1,]  5   10
# [2,] 15   20
# [3,] 25   30
# [4,] 35   40

# %% [markdown]
# ### 18. Division of a Matrix with a Constant

# %%
x <- matrix(nrow = 4, ncol = 2, data = 1:8, byrow = TRUE)
x
x / 2
# Out:
#      [,1] [,2]
# [1,] 1    2
# [2,] 3    4
# [3,] 5    6
# [4,] 7    8
#      [,1] [,2]
# [1,] 0.5  1
# [2,] 1.5  2
# [3,] 2.5  3
# [4,] 3.5  4

# %% [markdown]
# ### 19. Addition and Subtraction of Matrices

# %%
x <- matrix(nrow = 4, ncol = 2, data = 1:8, byrow = TRUE)
y <- matrix(nrow = 4, ncol = 2, data = 11:18, byrow = TRUE)

x
y

x + y
x - y
# Out:
#      [,1] [,2]
# [1,] 1    2
# [2,] 3    4
# [3,] 5    6
# [4,] 7    8
#      [,1] [,2]
# [1,] 11   12
# [2,] 13   14
# [3,] 15   16
# [4,] 17   18
#      [,1] [,2]
# [1,] 12   14
# [2,] 16   18
# [3,] 20   22
# [4,] 24   26
#      [,1] [,2]
# [1,] -10  -10
# [2,] -10  -10
# [3,] -10  -10
# [4,] -10  -10

# %% [markdown]
# ### 20. Scalar Multiplication and Matrix Expressions

# %%
x <- matrix(nrow = 4, ncol = 2, data = 1:8, byrow = TRUE)
x

4 * x

x + 4 * x

4 * x - x
# Out:
#      [,1] [,2]
# [1,] 1    2
# [2,] 3    4
# [3,] 5    6
# [4,] 7    8
#      [,1] [,2]
# [1,]  4    8
# [2,] 12   16
# [3,] 20   24
# [4,] 28   32
#      [,1] [,2]
# [1,]  5   10
# [2,] 15   20
# [3,] 25   30
# [4,] 35   40
#      [,1] [,2]
# [1,]  3    6
# [2,]  9   12
# [3,] 15   18
# [4,] 21   24

# %% [markdown]
# ### 21. Matrix Multiplication using `%*%`

# %%
x <- matrix(nrow = 4, ncol = 2, data = 1:8, byrow = TRUE)
y <- matrix(nrow = 2, ncol = 4, data = 11:18, byrow = TRUE)

x
y

x %*% y
y %*% x
# Out:
#      [,1] [,2]
# [1,] 1    2
# [2,] 3    4
# [3,] 5    6
# [4,] 7    8
#      [,1] [,2] [,3] [,4]
# [1,] 11   12   13   14
# [2,] 15   16   17   18
#      [,1] [,2] [,3] [,4]
# [1,]  41   44   47   50
# [2,]  93  100  107  114
# [3,] 145  156  167  178
# [4,] 197  212  227  242
#      [,1] [,2]
# [1,] 210  260
# [2,] 274  340

# %% [markdown]
# ### 22. Multiplication of X' and X

# %%
x <- matrix(nrow = 4, ncol = 2, data = 1:8, byrow = TRUE)
x

t(x)

t(x) %*% x

x %*% t(x)
# Out:
#      [,1] [,2]
# [1,] 1    2
# [2,] 3    4
# [3,] 5    6
# [4,] 7    8
#      [,1] [,2] [,3] [,4]
# [1,] 1    3    5    7
# [2,] 2    4    6    8
#      [,1] [,2]
# [1,]  84  100
# [2,] 100  120
#      [,1] [,2] [,3] [,4]
# [1,]  5   11   17    23
# [2,] 11   25   39    53
# [3,] 17   39   61    83
# [4,] 23   53   83   113

# %% [markdown]
# ### 23. Cross Product using `crossprod()`

# %%
x <- matrix(nrow = 4, ncol = 2, data = 1:8, byrow = TRUE)
x

crossprod(x)
# Out:
#      [,1] [,2]
# [1,] 1    2
# [2,] 3    4
# [3,] 5    6
# [4,] 7    8
#      [,1] [,2]
# [1,]  84  100
# [2,] 100  120

# %% [markdown]
# ### 24. Concatenating Matrices Row-wise using `rbind()`

# %%
x <- matrix(nrow = 3, ncol = 2, data = 1:6, byrow = TRUE)
y <- matrix(nrow = 3, ncol = 2, data = 11:16, byrow = TRUE)

x
y

rbind(x, y)
# Out:
#      [,1] [,2]
# [1,] 1    2
# [2,] 3    4
# [3,] 5    6
#      [,1] [,2]
# [1,] 11   12
# [2,] 13   14
# [3,] 15   16
#      [,1] [,2]
# [1,]  1    2
# [2,]  3    4
# [3,]  5    6
# [4,] 11   12
# [5,] 13   14
# [6,] 15   16

# %% [markdown]
# ### 25. Concatenating Matrices Column-wise using `cbind()`

# %%
x <- matrix(nrow = 3, ncol = 2, data = 1:6, byrow = TRUE)
y <- matrix(nrow = 3, ncol = 2, data = 11:16, byrow = TRUE)

x
y

cbind(x, y)
# Out:
#      [,1] [,2]
# [1,] 1    2
# [2,] 3    4
# [3,] 5    6
#      [,1] [,2]
# [1,] 11   12
# [2,] 13   14
# [3,] 15   16
#      [,1] [,2] [,3] [,4]
# [1,] 1    2    11   12
# [2,] 3    4    13   14
# [3,] 5    6    15   16

# %% [markdown]
# ### 26. Finding the Inverse of a Matrix using `solve()`

# %%
y <- matrix(
  nrow = 2,
  ncol = 2,
  byrow = TRUE,
  data = c(84, 100, 100, 120)
)

y
solve(y)
# Out:
#      [,1] [,2]
# [1,]  84  100
# [2,] 100  120
#      [,1]  [,2]
# [1,]  1.50 -1.25
# [2,] -1.25  1.05

# %% [markdown]
# ### 27. Finding Eigenvalues and Eigenvectors using `eigen()`

# %%
y <- matrix(
  nrow = 2,
  ncol = 2,
  byrow = TRUE,
  data = c(84, 100, 100, 120)
)

y
eigen(y)
# Out:
#      [,1] [,2]
# [1,]  84  100
# [2,] 100  120
# eigen() decomposition
# $values
# [1] 203.6070864   0.3929136
#
# $vectors
#           [,1]       [,2]
# [1,] 0.6414230 -0.7671874
# [2,] 0.7671874  0.6414230

# %% [markdown]
# ### 28. Logical and Comparison Operators
#
# Common operators used in R:
#
# - `>` Greater than
# - `>=` Greater than or equal to
# - `<` Less than
# - `<=` Less than or equal to
# - `==` Exactly equal to
# - `!=` Not equal to
# - `!` Logical NOT
# - `&`, `&&` Logical AND
# - `|`, `||` Logical OR
# - `xor(x, y)` Exclusive OR
# - `isTRUE(x)` Tests whether `x` is TRUE
# - `isFALSE(x)` Tests whether `x` is FALSE

# %% [markdown]
# ### 29. Example of `|` and `||`

# %%
x <- 8
(x < 10) || (x < 2)

x <- 18
(x < 10) || (x < 2)
# Out:
# [1] TRUE
# [1] FALSE

# %% [markdown]
# ### 30. Element-wise `|` versus `||`

# %%
x <- c(8, 18)

(x < 10) || (x < 2)
(x < 10) | (x < 2)
# Out:
# Error in (x < 10) || (x < 2): 'length = 2' in coercion to 'logical(1)'
# Traceback:

# %% [markdown]
# ### 31. Example of `&` and `&&`

# %%
x <- 5
(x < 10) && (x > 2)

x <- 15
(x < 10) && (x > 2)
# Out:
# [1] TRUE
# [1] FALSE

# %% [markdown]
# ### 32. Element-wise `&` versus `&&`

# %%
x <- c(8, 18)

(x < 10) && (x > 2)
(x < 10) & (x > 2)
# Out:
# Error in (x < 10) && (x > 2): 'length = 2' in coercion to 'logical(1)'
# Traceback:

# %% [markdown]
# ### 33. Filtering a Vector using Logical Conditions

# %%
x <- 1:6 # 1,2,3,4,5,6

(x > 2) & (x < 5)

x[(x > 2) & (x < 5)]
# Out:
# [1] FALSE FALSE  TRUE  TRUE FALSE FALSE
# [1] 3 4

# %% [markdown]
# ### 34. Filtering using Logical OR

# %%
x <- 1:6

(x > 2) | (x < 5)

x[(x > 2) | (x < 5)]
# Out:
# [1] TRUE TRUE TRUE TRUE TRUE TRUE
# [1] 1 2 3 4 5 6

# %% [markdown]
# ### 35. Understanding `&&` with a Vector

# %%
x <- 1:6

(x > 2) && (x < 5)

# Equivalent to checking only the first element
(x[1] > 2) & (x[1] < 5)
# Out:
# Error in (x > 2) && (x < 5): 'length = 6' in coercion to 'logical(1)'
# Traceback:

# %% [markdown]
# ### 36. Relational Operators
#
# `TRUE` and `FALSE` are logical constants in R.
#
# Also, in logical contexts, zero is treated as FALSE and non-zero numbers are treated as TRUE.

# %% [markdown]
# ### 37. Standard Logical Operations

# %%
x <- TRUE
y <- FALSE

x & y
x | y
!x
# Out:
# [1] FALSE
# [1] TRUE
# [1] FALSE

# %% [markdown]
# ### 38. Checking Logical Results with `is.logical()`

# %%
x <- 5

Logical1 <- (x > 2)
Logical1
is.logical(Logical1)

Logical2 <- (x < 10)
Logical2
is.logical(Logical2)

Logical3 <- (x != 5)
Logical3
is.logical(Logical3)
# Out:
# [1] TRUE
# [1] TRUE
# [1] TRUE
# [1] TRUE
# [1] FALSE
# [1] TRUE

# %% [markdown]
# ### 39. More Logical Expressions

# %%
x <- 5

Logical4 <- (2 * x > 11)
Logical4
is.logical(Logical4)

Logical5 <- (3 * x < 20)
Logical5
is.logical(Logical5)
# Out:
# [1] FALSE
# [1] TRUE
# [1] TRUE
# [1] TRUE

# %% [markdown]
# ### 40. Basic Relational Comparisons

# %%
8 > 7
7 < 5
7 > 7
7 >= 7
8 < 8
8 <= 8

8 != 9
9 != 9
7 == 7
7 == 8
# Out:
# [1] TRUE
# [1] FALSE
# [1] FALSE
# [1] TRUE
# [1] FALSE
# [1] TRUE
# [1] TRUE
# [1] FALSE
# [1] TRUE
# [1] FALSE

# %% [markdown]
# ### 41. Logical NOT

# %%
x <- TRUE
!x
# Out:
# [1] FALSE

# %% [markdown]
# ### 42. Relational Comparisons between Vectors

# %%
x <- c(1, 2, 3)
y <- c(4, 5, 6)

x > y
x < y
x != y
x == y
# Out:
# [1] FALSE FALSE FALSE
# [1] TRUE TRUE TRUE
# [1] TRUE TRUE TRUE
# [1] FALSE FALSE FALSE

# %% [markdown]
# ### 43. Using `isTRUE()` and `isFALSE()`

# %%
isTRUE(8 < 6)
isTRUE(8 > 6)

isFALSE(5 < 8)
isFALSE(5 > 8)
# Out:
# [1] FALSE
# [1] TRUE
# [1] FALSE
# [1] TRUE
