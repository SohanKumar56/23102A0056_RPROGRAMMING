# %% [markdown]
# <a href="https://colab.research.google.com/github/SohanKumar56/23102A0056_RPROGRAMMING/blob/main/Week3_R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name: Sohan Kumar
#
# Roll no: 23102A0056
#
# Branch: CMPN-A

# %%
#addition with data vectors

c(2,3,5,7) + c(-2,-3,-4,-6)
# Out:
# [1] 0 0 1 1

# %%
# R as a calculator

2^3

2**3

2^0.5

2**0.5

2**-0.5
# Out:
# [1] 8
# [1] 8
# [1] 1.414214
# [1] 1.414214
# [1] 0.7071068

# %%
# Power Operator with scalar

c(2,3,4,7)^2
# Out:
# [1]  4  9 16 49

# %%
#power operation with vector
c(2,3,4,7)^c(2,3)
# Out:
# [1]   4  27  16 343

# %%
c(2,3,4,5)**c(2,3,4)
# Out:
# Warning message in c(2, 3, 4, 5)^c(2, 3, 4):
# “longer object length is not a multiple of shorter object length”
# [1]   4  27 256  25

# %%
#integer division with scalar
c(2,3,4,5)%/%2
# Out:
# [1] 1 1 2 2

# %%
#integer division with data vector
c(2,3,4,5)%/%c(2,3)
# Out:
# [1] 1 1 2 1

# %%
#integer division with scalar
c(2,3,4,5)%/%c(2,3,4)
# Out:
# Warning message in c(2, 3, 4, 5)%/%c(2, 3, 4):
# “longer object length is not a multiple of shorter object length”
# [1] 1 1 1 2

# %%
#modulo division (x mod y) with scalars

2 %% 2

3 %% 2

7 %% 3

7 %% 4
# Out:
# [1] 0
# [1] 1
# [1] 1
# [1] 3

# %%
#modulo division of vectors (x mod y) with scalars

c(2,3,4,5) %% 2
# Out:
# [1] 0 1 0 1

# %%
#modulo division of vectors (x mod y) with data vectors

c(2,3,4,5) %% c(2,4)
# Out:
# [1] 0 3 0 1

# %%
c(2,3,4,5) %% c(2,4,5)
# Out:
# Warning message in c(2, 3, 4, 5)%%c(2, 4, 5):
# “longer object length is not a multiple of shorter object length”
# [1] 0 3 4 1

# %%
#Maximum

max(2.3, 4.5, 4.7, -4)


max(c(2.3, 4.5, 4.7, -4))
# Out:
# [1] 4.7
# [1] 4.7

# %%
#Minimum

min(2.3, 4.5, 4.7, -4)


min(c(2.3, 4.5, 4.7, -4))
# Out:
# [1] -4
# [1] -4

# %%
# mean

mean(2,3,4)
# Out:
# [1] 2

# %%
mean(c(2,3,4))
# Out:
# [1] 3

# %% [markdown]
# ###Overview of further functions

# %%
abs(-4)
# Out:
# [1] 4

# %%
abs(c(-2,4,-3,-8.9))
# Out:
# [1] 2.0 4.0 3.0 8.9

# %%
sqrt(4)
# Out:
# [1] 2

# %%
sqrt(c(4,9,18,25))
# Out:
# [1] 2.000000 3.000000 4.242641 5.000000

# %%
sum(c(2,3,5,7))
# Out:
# [1] 17

# %%
prod(c(2,3,4,5))
# Out:
# [1] 120

# %%
round(1.23)
# Out:
# [1] 1

# %%
round(1.82)
# Out:
# [1] 2

# %%
log(10)
# Out:
# [1] 2.302585

# %%
log(exp(1))
# Out:
# [1] 1

# %%
log(c(10,100,1000))
# Out:
# [1] 2.302585 4.605170 6.907755

# %%
log10(10)
# Out:
# [1] 1

# %%
log10(100)
# Out:
# [1] 2

# %%
log10(2)
# Out:
# [1] 0.30103

# %%
log10(c(10,100,1000))
# Out:
# [1] 1 2 3

# %%
#Assignments


x1= c(1,2,3,4)
x1
# Out:
# [1] 1 2 3 4

# %%
x2= x1^2
x2
# Out:
# [1]  1  4  9 16

# %%
c(1,2,3,4) + sum(c(1,2,3,4)) + prod(c(1,2))
# Out:
# [1] 13 14 15 16

# %%
c(1,2,3,4) - sum(c(1,2,3,4)) * prod(c(1,2))
# Out:
# [1] -19 -18 -17 -16

# %%
abs(c(1,2,3,4) - sum(c(1,2,3,4)) * prod(c(1,2)))
# Out:
# [1] 19 18 17 16

# %% [markdown]
# #Matrix

# %%
x=matrix(nrow=4, ncol=2, data=c(1,2,3,4,5,6,7,8))

# %%
x
# Out:
#      [,1] [,2]
# [1,] 1    5
# [2,] 2    6
# [3,] 3    7
# [4,] 4    8

# %%
x[3,2]
# Out:
# [1] 7

# %%
x=matrix(nrow=4, ncol=2, data=c(1,2,3,4,5,6,7,8), byrow=TRUE)

# %%
x
# Out:
#      [,1] [,2]
# [1,] 1    2
# [2,] 3    4
# [3,] 5    6
# [4,] 7    8

# %%
dim(x)
# Out:
# [1] 4 2

# %%
nrow(x)
# Out:
# [1] 4

# %%
ncol(x)
# Out:
# [1] 2

# %%
mode(x)
# Out:
# [1] "numeric"

# %%
attributes(x)
# Out:
# $dim
# [1] 4 2
